# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanjalipatel/priyanjalipatel.github.io/blob/master/Copy_of_landsat_unet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unet for Landsat images
# This notebook adapts the unet implementation from https://github.com/milesial/Pytorch-UNet/

# %%
# To save checkpoints
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Dowload data
# !stat split_256x256_0.07_2009.zip || gdown 1lg8nr-6-4tyufZiuXfdqXdoq5MNz5Grl
# !mkdir -p data
# !unzip -o split_256x256_0.07_2009.zip -d data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/270_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/270_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/270_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/271_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/271_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/271_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/271_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/271_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/271_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/271_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/271_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/272_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/272_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/272_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/272_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/272_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/272_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/272_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/272_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/273_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/273_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/273_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/273_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/273_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/273_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/273_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/273_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/274_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/274_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/274_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/274_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/274_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/274_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/274_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/274_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/275_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/275_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/275_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/275_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/275_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/275_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/275_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/275_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/276_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/276_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/276_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/276_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/276_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/276_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/276_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/276_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/277_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/277_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/277_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/277_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/277_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/277_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/277_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/277_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/278_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/278_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/278_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/278_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/278_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/278_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/278_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/278_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/279_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/279_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/279_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/279_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/279_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/279_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/279_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/279_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/27_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/27_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/27_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/27_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/27_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/27_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/27_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/27_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/280_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/280_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/280_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/280_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/280_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/280_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/280_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/280_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/281_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/281_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/281_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/281_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/281_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/281_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/281_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/281_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/282_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/282_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/282_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/282_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/282_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/282_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/282_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/282_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/283_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/283_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/283_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/283_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/283_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/283_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/283_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/283_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/284_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/284_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/284_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/284_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/284_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/284_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/284_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/284_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/285_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/285_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/285_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/285_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/285_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/285_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/285_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/285_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/286_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/286_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/286_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/286_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/286_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/286_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/286_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/286_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/287_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/287_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/287_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/287_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/287_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/287_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/287_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/287_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/288_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/288_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/288_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/288_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/288_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/288_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/288_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/288_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/289_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/289_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/289_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/289_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/289_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/289_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/289_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/289_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/28_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/28_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/28_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/28_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/28_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/28_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/28_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/28_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/290_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/290_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/290_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/290_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/290_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/290_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/290_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/290_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/291_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/291_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/291_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/291_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/291_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/291_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/291_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/291_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/292_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/292_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/292_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/292_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/292_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/292_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/292_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/292_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/293_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/293_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/293_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/293_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/293_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/293_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/293_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/293_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/294_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/294_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/294_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/294_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/294_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/294_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/294_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/294_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/295_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/295_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/295_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/295_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/295_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/295_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/295_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/295_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/296_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/296_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/296_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/296_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/296_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/296_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/296_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/296_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/297_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/297_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/297_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/297_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/297_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/297_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/297_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/297_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/298_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/298_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/298_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/298_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/298_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/298_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/298_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/298_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/299_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/299_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/299_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/299_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/299_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/299_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/299_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/299_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/29_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/29_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/29_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/29_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/29_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/29_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/29_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/29_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/2_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/2_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/2_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/2_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/2_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/2_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/2_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/2_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/30_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/30_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/30_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/30_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/30_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/30_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/30_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/30_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/31_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/31_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/31_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/31_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/31_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/31_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/31_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/31_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/32_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/32_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/32_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/32_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/32_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/32_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/32_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/32_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/33_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/33_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/33_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/33_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/33_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/33_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/33_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/33_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/34_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/34_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/34_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/34_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/34_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/34_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/34_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/34_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/35_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/35_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/35_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/35_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/35_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/35_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/35_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/35_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/36_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/36_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/36_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/36_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/36_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/36_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/36_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/36_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/37_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/37_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/37_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/37_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/37_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/37_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/37_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/37_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/38_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/38_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/38_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/38_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/38_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/38_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/38_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/38_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/39_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/39_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/39_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/39_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/39_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/39_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/39_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/39_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/3_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/3_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/3_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/3_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/3_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/3_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/3_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/3_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/40_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/40_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/40_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/40_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/40_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/40_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/40_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/40_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/41_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/41_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/41_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/41_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/41_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/41_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/41_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/41_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/42_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/42_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/42_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/42_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/42_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/42_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/42_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/42_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/43_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/43_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/43_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/43_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/43_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/43_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/43_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/43_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/44_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/44_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/44_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/44_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/44_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/44_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/44_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/44_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/45_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/45_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/45_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/45_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/45_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/45_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/45_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/45_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/46_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/46_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/46_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/46_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/46_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/46_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/46_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/46_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/47_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/47_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/47_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/47_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/47_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/47_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/47_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/47_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/48_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/48_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/48_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/48_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/48_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/48_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/48_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/48_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/49_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/49_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/49_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/49_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/49_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/49_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/49_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/49_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/4_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/4_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/4_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/4_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/4_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/4_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/4_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/4_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/50_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/50_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/50_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/50_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/50_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/50_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/50_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/50_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/51_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/51_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/51_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/51_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/51_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/51_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/51_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/51_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/52_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/52_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/52_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/52_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/52_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/52_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/52_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/52_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/53_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/53_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/53_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/53_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/53_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/53_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/53_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/53_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/54_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/54_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/54_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/54_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/54_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/54_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/54_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/54_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/55_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/55_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/55_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/55_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/55_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/55_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/55_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/55_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/56_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/56_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/56_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/56_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/56_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/56_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/56_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/56_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/57_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/57_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/57_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/57_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/57_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/57_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/57_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/57_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/58_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/58_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/58_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/58_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/58_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/58_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/58_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/58_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/59_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/59_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/59_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/59_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/59_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/59_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/59_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/59_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/5_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/5_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/5_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/5_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/5_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/5_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/5_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/5_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/60_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/60_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/60_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/60_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/60_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/60_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/60_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/60_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/61_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/61_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/61_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/61_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/61_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/61_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/61_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/61_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/62_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/62_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/62_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/62_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/62_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/62_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/62_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/62_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/63_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/63_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/63_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/63_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/63_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/63_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/63_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/63_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/64_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/64_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/64_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/64_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/64_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/64_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/64_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/64_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/65_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/65_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/65_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/65_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/65_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/65_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/65_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/65_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/66_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/66_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/66_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/66_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/66_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/66_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/66_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/66_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/67_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/67_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/67_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/67_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/67_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/67_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/67_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/67_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/68_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/68_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/68_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/68_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/68_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/68_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/68_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/68_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/69_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/69_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/69_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/69_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/69_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/69_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/69_B7.tif
#  extracting: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/69_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/6_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/6_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/6_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/6_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/6_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/6_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/6_B7.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/6_mask.png
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/70_B1.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/70_B2.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/70_B3.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/70_B4.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/70_B5.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/70_B6.tif
#   inflating: data/2009/LT05_L1TP_147037_20090813_20200827_02_T1/70_B7.tif
# ...
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/21_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/22_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/22_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/22_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/22_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/22_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/22_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/22_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/22_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/23_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/23_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/23_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/23_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/23_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/23_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/23_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/23_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/24_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/24_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/24_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/24_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/24_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/24_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/24_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/24_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/25_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/25_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/25_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/25_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/25_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/25_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/25_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/25_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/26_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/26_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/26_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/26_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/26_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/26_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/26_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/26_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/27_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/27_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/27_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/27_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/27_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/27_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/27_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/27_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/28_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/28_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/28_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/28_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/28_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/28_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/28_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/28_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/29_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/29_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/29_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/29_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/29_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/29_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/29_B7.tif
#  extracting: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/29_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/2_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/2_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/2_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/2_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/2_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/2_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/2_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/2_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/30_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/30_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/30_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/30_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/30_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/30_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/30_B7.tif
#  extracting: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/30_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/31_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/31_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/31_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/31_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/31_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/31_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/31_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/31_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/32_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/32_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/32_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/32_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/32_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/32_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/32_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/32_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/33_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/33_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/33_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/33_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/33_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/33_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/33_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/33_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/34_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/34_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/34_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/34_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/34_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/34_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/34_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/34_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/35_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/35_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/35_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/35_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/35_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/35_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/35_B7.tif
#  extracting: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/35_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/36_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/36_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/36_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/36_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/36_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/36_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/36_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/36_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/37_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/37_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/37_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/37_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/37_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/37_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/37_B7.tif
#  extracting: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/37_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/38_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/38_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/38_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/38_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/38_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/38_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/38_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/38_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/39_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/39_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/39_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/39_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/39_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/39_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/39_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/39_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/3_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/3_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/3_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/3_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/3_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/3_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/3_B7.tif
#  extracting: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/3_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/4_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/4_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/4_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/4_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/4_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/4_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/4_B7.tif
#  extracting: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/4_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/5_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/5_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/5_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/5_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/5_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/5_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/5_B7.tif
#  extracting: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/5_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/6_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/6_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/6_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/6_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/6_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/6_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/6_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/6_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/7_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/7_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/7_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/7_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/7_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/7_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/7_B7.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/7_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/8_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/8_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/8_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/8_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/8_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/8_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/8_B7.tif
#  extracting: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/8_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/9_B1.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/9_B2.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/9_B3.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/9_B4.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/9_B5.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/9_B6.tif
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/9_B7.tif
#  extracting: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/9_mask.png
#   inflating: data/2009/LT05_L1TP_149036_20090827_20200825_02_T1/full_mask.png

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms.functional as TF
from torch import optim

import cv2

from torch.utils.data import Dataset, DataLoader, random_split
from pathlib import Path
import os

import numpy as np
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# # Creating the network

# %%
# https://github.com/milesial/Pytorch-UNet/blob/master/unet/unet_parts.py
""" Parts of the U-Net model """

class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)


class Down(nn.Module):
    """Downscaling with maxpool then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)


class Up(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels, bilinear=True):
        super().__init__()

        # if bilinear, use the normal convolutions to reduce the number of channels
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
            self.conv = DoubleConv(in_channels, out_channels, in_channels // 2)
        else:
            self.up = nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size=2, stride=2)
            self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        # if you have padding issues, see
        # https://github.com/HaiyongJiang/U-Net-Pytorch-Unstructured-Buggy/commit/0e854509c2cea854e247a9c615f175f76fbb2e3a
        # https://github.com/xiaopeng-liao/Pytorch-UNet/commit/8ebac70e633bac59fc22bb5195e513d5832fb3bd
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)


class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        return self.conv(x)

# %%
""" Full assembly of the parts to form the complete network """

class UNet(nn.Module):
    def __init__(self, n_channels, n_classes, bilinear=False):
        super(UNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.bilinear = bilinear

        self.inc = (DoubleConv(n_channels, 64))
        self.down1 = (Down(64, 128))
        self.down2 = (Down(128, 256))
        self.down3 = (Down(256, 512))
        factor = 2 if bilinear else 1
        self.down4 = (Down(512, 1024 // factor))
        self.up1 = (Up(1024, 512 // factor, bilinear))
        self.up2 = (Up(512, 256 // factor, bilinear))
        self.up3 = (Up(256, 128 // factor, bilinear))
        self.up4 = (Up(128, 64, bilinear))
        self.outc = (OutConv(64, n_classes))

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        logits = self.outc(x)
        return logits

    def use_checkpointing(self):
        self.inc = torch.utils.checkpoint(self.inc)
        self.down1 = torch.utils.checkpoint(self.down1)
        self.down2 = torch.utils.checkpoint(self.down2)
        self.down3 = torch.utils.checkpoint(self.down3)
        self.down4 = torch.utils.checkpoint(self.down4)
        self.up1 = torch.utils.checkpoint(self.up1)
        self.up2 = torch.utils.checkpoint(self.up2)
        self.up3 = torch.utils.checkpoint(self.up3)
        self.up4 = torch.utils.checkpoint(self.up4)
        self.outc = torch.utils.checkpoint(self.outc)

# %% [markdown]
# # Creating the dataset

# %%
class LandsatDataset(Dataset):
    def __init__(self, scenes_dir):
        self.scenes_dir = Path(scenes_dir)
        # p.parent -> folder where patch is
        # p.name.split -> patch idx in folder
        # self.patches = [(p.parent, p.name.split("_", 1)[0]) for p in scenes_dir.rglob("*B4.tif") if cv2.imread(str(p), cv2.IMREAD_UNCHANGED).shape == (256, 256)]
        self.patches = [(p.parent, p.name.split("_", 1)[0]) for p in scenes_dir.rglob("*B4.tif")]

    def __len__(self):
        return len(self.patches)

    def __getitem__(self, idx):
        scene_dir, local_idx = self.patches[idx]
        # print(f"Scene dir: {scene_dir}")
        # print(f"Local index: {local_idx}")


        unordered_tif_files = [f for f in scene_dir.glob(f"{local_idx}_B*.tif") if "(" not in f.name]
        tif_files = sorted(unordered_tif_files, key=lambda x: int(x.stem.rsplit("_", 1)[-1].removeprefix("B")))
        imgs = [np.array(cv2.imread(str(tif_file), cv2.IMREAD_UNCHANGED)) for tif_file in tif_files]
        out_volume = np.stack(imgs, axis=0)

        assert np.max(out_volume) <= 255, "TIFF values higher than expected"
        assert out_volume.shape == (7, 256, 256), f"Error in scene {scene_dir} \n\tError in id {local_idx}"

        # preprocess tiff files
        out_volume = out_volume.astype(np.float64) / 255


        mask_file = next(iter(scene_dir.glob(f"{local_idx}_mask.png")))
        mask = cv2.imread(str(mask_file), cv2.IMREAD_GRAYSCALE)

        # preprocess mask
        mask[mask < 128] = 0
        mask[mask >= 128] = 1


        # pil: width, height
        # numpy: height, width
        # pil to tensor: channels, height, width
        # opencv: height, width, channels

        return {
            "image": torch.Tensor(out_volume.copy()).float().contiguous(),
            "mask": torch.Tensor(mask.copy()).long().contiguous(),
            # "global_idx": idx,
        }

# %% [markdown]
# # Dice loss

# %%
def dice_coeff(input, target, reduce_batch_first: bool = False, epsilon: float = 1e-6):
    # Average of Dice coefficient for all batches, or for a single mask
    # print(f"Input shape: {input.shape}")
    # print(f"Target shape: {target.shape}")
    # print(f"Input: {input}")
    # print(f"Target: {target}")
    assert input.size() == target.size()
    assert input.dim() == 3 or not reduce_batch_first

    sum_dim = (-1, -2) if input.dim() == 2 or not reduce_batch_first else (-1, -2, -3)

    inter = 2 * (input * target).sum(dim=sum_dim)
    sets_sum = input.sum(dim=sum_dim) + target.sum(dim=sum_dim)
    sets_sum = torch.where(sets_sum == 0, inter, sets_sum)

    dice = (inter + epsilon) / (sets_sum + epsilon)
    return dice.mean()


def multiclass_dice_coeff(input, target, reduce_batch_first: bool = False, epsilon: float = 1e-6):
    # Average of Dice coefficient for all classes
    return dice_coeff(input.flatten(0, 1), target.flatten(0, 1), reduce_batch_first, epsilon)


def dice_loss(input, target, multiclass: bool = False):
    # Dice loss (objective to minimize) between 0 and 1
    fn = multiclass_dice_coeff if multiclass else dice_coeff
    return 1 - fn(input, target, reduce_batch_first=True)

# %% [markdown]
# # Evaluate function

# %%
@torch.inference_mode()
def evaluate(net, dataloader, device, amp):
    net.eval()
    num_val_batches = len(dataloader)
    dice_score = 0


    # iterate over the validation set
    with torch.autocast(device.type if device.type != 'mps' else 'cpu', enabled=amp):
        for batch in tqdm(dataloader, total=num_val_batches, desc='Validation round', unit='batch', leave=False):
            image, mask_true = batch['image'], batch['mask']
            # image, mask_true, global_idx = batch['image'], batch['mask'], batch["global_idx"]
            # print(f"Current example: {global_idx}")


            # move images and labels to correct device and type
            image = image.to(device=device, dtype=torch.float32, memory_format=torch.channels_last)
            mask_true = mask_true.to(device=device, dtype=torch.long)

            # predict the mask
            mask_pred = net(image)
            mask_pred = torch.squeeze(mask_pred, dim=1)

            if net.n_classes == 1:
                assert mask_true.min() >= 0 and mask_true.max() <= 1, 'True mask indices should be in [0, 1]'
                mask_pred = (F.sigmoid(mask_pred) > 0.5).float()
                # compute the Dice score
                dice_score += dice_coeff(mask_pred, mask_true, reduce_batch_first=False)
            else:
                assert mask_true.min() >= 0 and mask_true.max() < net.n_classes, 'True mask indices should be in [0, n_classes['
                # convert to one-hot format
                mask_true = F.one_hot(mask_true, net.n_classes).permute(0, 3, 1, 2).float()
                mask_pred = F.one_hot(mask_pred.argmax(dim=1), net.n_classes).permute(0, 3, 1, 2).float()
                # compute the Dice score, ignoring background
                dice_score += multiclass_dice_coeff(mask_pred[:, 1:], mask_true[:, 1:], reduce_batch_first=False)

    net.train()
    return dice_score / max(num_val_batches, 1)

# %% [markdown]
# # Config

# %%
#  Data
data_path = Path("/content/data/2009")
val_percent=0.15
batch_size=32
n_channels=7
n_classes=1

#  Training
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
learning_rate=0.01
weight_decay=0
momentum=0
amp=False
epochs=30
gradient_clipping=1.0

#  Checkpoints
save_checkpoint=True
dir_checkpoint=Path("/content/drive/MyDrive/Omdena/Ladakh/checkpoints")

# Dataset
dataset = LandsatDataset(data_path)

n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train_set, val_set = random_split(dataset, [n_train, n_val], generator=torch.Generator().manual_seed(0))

loader_args = dict(batch_size=batch_size, num_workers=os.cpu_count(), pin_memory=True)
train_loader = DataLoader(train_set, shuffle=True, **loader_args)
val_loader = DataLoader(val_set, shuffle=False, drop_last=True, **loader_args)


print(f'''
    Data path:       {data_path}
    Epochs:          {epochs}
    Batch size:      {batch_size}
    Learning rate:   {learning_rate}
    Training size:   {n_train}
    Validation size: {n_val}
    Checkpoints:     {save_checkpoint}
    Device:          {device.type}
    Mixed Precision: {amp}
''')

# Change here to adapt to your data
# n_channels=3 for RGB images
# n_classes is the number of probabilities you want to get per pixel
model = UNet(n_channels=n_channels, n_classes=n_classes, bilinear=False)
model = model.to(device=device, memory_format=torch.channels_last)

print(f'Network:\n'
                f'\t{model.n_channels} input channels\n'
                f'\t{model.n_classes} output channels (classes)\n'
                f'\t{"Bilinear" if model.bilinear else "Transposed conv"} upscaling')


optimizer = optim.RMSprop(model.parameters(),
                            lr=learning_rate, weight_decay=weight_decay, momentum=momentum, foreach=True)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max', patience=5)  # goal: maximize Dice score
grad_scaler = torch.cuda.amp.GradScaler(enabled=amp)
criterion = nn.CrossEntropyLoss() if model.n_classes > 1 else nn.BCEWithLogitsLoss()
# Out:
#     Data path:       /content/data/2009
#     Epochs:          30
#     Batch size:      32
#     Learning rate:   0.01
#     Training size:   1920
#     Validation size: 338
#     Checkpoints:     True
#     Device:          cuda
#     Mixed Precision: False
#
# Network:
# 	7 input channels
# 	1 output channels (classes)
# 	Transposed conv upscaling

# %% [markdown]
# # Training

# %%
# Training
global_step = 0
for epoch in range(1, epochs + 1):
    model.train()
    epoch_loss = 0
    with tqdm(total=n_train, desc=f'Epoch {epoch}/{epochs}', unit='img') as pbar:
        for batch in train_loader:
            images, true_masks = batch['image'], batch['mask']

            assert images.shape[1] == model.n_channels, \
                f'Network has been defined with {model.n_channels} input channels, ' \
                f'but loaded images have {images.shape[1]} channels. Please check that ' \
                'the images are loaded correctly.'

            images = images.to(device=device, dtype=torch.float32, memory_format=torch.channels_last)
            true_masks = true_masks.to(device=device, dtype=torch.long)

            with torch.autocast(device.type if device.type != 'mps' else 'cpu', enabled=amp):
                masks_pred = model(images)
                if model.n_classes == 1:
                    loss = criterion(masks_pred.squeeze(1), true_masks.float())
                    loss += dice_loss(F.sigmoid(masks_pred.squeeze(1)), true_masks.float(), multiclass=False)
                else:
                    loss = criterion(masks_pred, true_masks)
                    loss += dice_loss(
                        F.softmax(masks_pred, dim=1).float(),
                        F.one_hot(true_masks, model.n_classes).permute(0, 3, 1, 2).float(),
                        multiclass=True
                    )

            optimizer.zero_grad(set_to_none=True)
            grad_scaler.scale(loss).backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), gradient_clipping)
            grad_scaler.step(optimizer)
            grad_scaler.update()

            pbar.update(images.shape[0])
            global_step += 1
            epoch_loss += loss.item()
            pbar.set_postfix(**{'loss (batch)': loss.item()})

            # Evaluation round
            division_step = (n_train // (5 * batch_size))
            if division_step > 0:
                if global_step % division_step == 0:
                    val_score = evaluate(model, val_loader, device, amp)
                    scheduler.step(val_score)

                    print('Validation Dice score: {}'.format(val_score))

    if save_checkpoint:
        Path(dir_checkpoint).mkdir(parents=True, exist_ok=True)
        state_dict = model.state_dict()
        torch.save(state_dict, str(dir_checkpoint / 'checkpoint_epoch{}.pth'.format(epoch)))
        print(f'Checkpoint {epoch} saved!')
# Out:
# Epoch 1/30:  20%|██        | 384/1920 [00:38<01:51, 13.76img/s, loss (batch)=0.755]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:16,  1.88s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.27s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.10s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.04batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.09batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.12batch/s]
# Validation round:  80%|████████  | 8/10 [00:07<00:01,  1.14batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.16batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.17batch/s]
# Validation Dice score: 0.34785574674606323
# Epoch 1/30:  40%|████      | 768/1920 [01:15<01:26, 13.39img/s, loss (batch)=0.733]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:19,  2.19s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:11,  1.41s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:08,  1.16s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.05s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.09batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.11batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.13batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.14batch/s]
# Validation Dice score: 0.6960692405700684
# Epoch 1/30:  60%|██████    | 1152/1920 [01:54<00:59, 12.95img/s, loss (batch)=0.666]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:16,  1.79s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.7353904843330383
# Epoch 1/30:  80%|████████  | 1536/1920 [02:34<00:29, 12.83img/s, loss (batch)=0.56]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.69s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.22s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.07s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:05,  1.00batch/s]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.05batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.07batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.09batch/s]
# Validation round:  80%|████████  | 8/10 [00:07<00:01,  1.10batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.11batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.12batch/s]
# Validation Dice score: 0.7484559416770935
# Epoch 1/30: 100%|██████████| 1920/1920 [03:12<00:00, 12.96img/s, loss (batch)=0.613]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.75s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.24s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:07<00:01,  1.10batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Epoch 1/30: 100%|██████████| 1920/1920 [03:22<00:00,  9.47img/s, loss (batch)=0.613]
# Validation Dice score: 0.7390252947807312
# Checkpoint 1 saved!
# Epoch 2/30:  20%|██        | 384/1920 [00:30<01:58, 13.00img/s, loss (batch)=0.606]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.70s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.23s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.08s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:07<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.7552590370178223
# Epoch 2/30:  40%|████      | 768/1920 [01:09<01:29, 12.86img/s, loss (batch)=0.555]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:20,  2.33s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:11,  1.48s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.21s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.08s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:05,  1.02s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.03batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.06batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Validation Dice score: 0.7315492033958435
# Epoch 2/30:  60%|██████    | 1152/1920 [01:48<01:00, 12.78img/s, loss (batch)=0.546]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:21,  2.44s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:12,  1.53s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.26s/batch]
# Validation round:  40%|████      | 4/10 [00:05<00:06,  1.12s/batch]
# Validation round:  50%|█████     | 5/10 [00:06<00:05,  1.04s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.01batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.04batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.07batch/s]
# Epoch 2/30:  60%|██████    | 1152/1920 [01:59<01:00, 12.78img/s, loss (batch)=0.546]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Validation Dice score: 0.7521684765815735
# Epoch 2/30:  80%|████████  | 1536/1920 [02:28<00:29, 12.84img/s, loss (batch)=0.593]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.76s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.25s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.03s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.7351149320602417
# Epoch 2/30: 100%|██████████| 1920/1920 [03:07<00:00, 12.85img/s, loss (batch)=0.516]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.76s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.25s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Epoch 2/30: 100%|██████████| 1920/1920 [03:17<00:00,  9.70img/s, loss (batch)=0.516]
# Validation Dice score: 0.7592687606811523
# Checkpoint 2 saved!
# Epoch 3/30:  20%|██        | 384/1920 [00:30<01:57, 13.06img/s, loss (batch)=0.627]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:14,  1.66s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.21s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.06s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:05,  1.00batch/s]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.04batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.07batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:07<00:01,  1.10batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.11batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.7521023750305176
# Epoch 3/30:  40%|████      | 768/1920 [01:09<01:30, 12.77img/s, loss (batch)=0.633]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:16,  1.81s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.27s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.10s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.5011153817176819
# Epoch 3/30:  60%|██████    | 1152/1920 [01:48<01:00, 12.80img/s, loss (batch)=0.616]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:21,  2.37s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:12,  1.50s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.23s/batch]
# Validation round:  40%|████      | 4/10 [00:05<00:06,  1.10s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:05,  1.03s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.02batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.05batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.07batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Validation Dice score: 0.7485918998718262
# Epoch 3/30:  80%|████████  | 1536/1920 [02:28<00:30, 12.77img/s, loss (batch)=0.613]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.77s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.10s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.03s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Epoch 3/30:  80%|████████  | 1536/1920 [02:38<00:30, 12.77img/s, loss (batch)=0.613]
# Validation Dice score: 0.7537752985954285
# Epoch 3/30: 100%|██████████| 1920/1920 [03:07<00:00, 12.83img/s, loss (batch)=0.544]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.77s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Epoch 3/30: 100%|██████████| 1920/1920 [03:17<00:00,  9.72img/s, loss (batch)=0.544]
# Validation Dice score: 0.7332538366317749
# Checkpoint 3 saved!
# Epoch 4/30:  20%|██        | 384/1920 [00:30<01:58, 12.92img/s, loss (batch)=0.634]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.76s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.10s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.01batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.04batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.7207125425338745
# Epoch 4/30:  40%|████      | 768/1920 [01:09<01:29, 12.87img/s, loss (batch)=0.493]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.77s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.25s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.7630045413970947
# Epoch 4/30:  60%|██████    | 1152/1920 [01:48<01:00, 12.77img/s, loss (batch)=0.532]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.77s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.7667768597602844
# Epoch 4/30:  80%|████████  | 1536/1920 [02:27<00:30, 12.78img/s, loss (batch)=0.409]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:22,  2.47s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:12,  1.55s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.26s/batch]
# Validation round:  40%|████      | 4/10 [00:05<00:06,  1.12s/batch]
# Validation round:  50%|█████     | 5/10 [00:06<00:05,  1.04s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.01batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.05batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.07batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Validation Dice score: 0.7708331942558289
# Epoch 4/30: 100%|██████████| 1920/1920 [03:07<00:00, 12.81img/s, loss (batch)=0.629]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.69s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.22s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.08s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:07<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Epoch 4/30: 100%|██████████| 1920/1920 [03:17<00:00,  9.71img/s, loss (batch)=0.629]
# Validation Dice score: 0.7744544148445129
# Checkpoint 4 saved!
# Epoch 5/30:  20%|██        | 384/1920 [00:30<01:57, 13.06img/s, loss (batch)=0.504]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:16,  1.85s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.29s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.11s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.04s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.01batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.04batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.06batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.778298020362854
# Epoch 5/30:  40%|████      | 768/1920 [01:09<01:29, 12.81img/s, loss (batch)=0.474]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.77s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.25s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.7812308669090271
# Epoch 5/30:  60%|██████    | 1152/1920 [01:48<01:00, 12.76img/s, loss (batch)=0.396]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.74s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.24s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.08s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.7809440493583679
# Epoch 5/30:  80%|████████  | 1536/1920 [02:28<00:30, 12.78img/s, loss (batch)=0.487]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:21,  2.34s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:11,  1.49s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.22s/batch]
# Validation round:  40%|████      | 4/10 [00:05<00:06,  1.10s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:05,  1.03s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.02batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.05batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.07batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Validation Dice score: 0.7853969931602478
# Epoch 5/30: 100%|██████████| 1920/1920 [03:07<00:00, 12.80img/s, loss (batch)=0.584]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.77s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.12s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.03s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Epoch 5/30: 100%|██████████| 1920/1920 [03:17<00:00,  9.70img/s, loss (batch)=0.584]
# Validation Dice score: 0.7774530053138733
# Checkpoint 5 saved!
# Epoch 6/30:  20%|██        | 384/1920 [00:30<01:57, 13.05img/s, loss (batch)=0.473]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.73s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.25s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.7890052795410156
# Epoch 6/30:  40%|████      | 768/1920 [01:09<01:30, 12.80img/s, loss (batch)=0.448]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.74s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.24s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.7906652092933655
# Epoch 6/30:  60%|██████    | 1152/1920 [01:48<00:59, 12.84img/s, loss (batch)=0.395]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:20,  2.24s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:11,  1.45s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.20s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.08s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:05,  1.01s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.03batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.06batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Validation Dice score: 0.7920164465904236
# Epoch 6/30:  80%|████████  | 1536/1920 [02:28<00:30, 12.73img/s, loss (batch)=0.462]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:22,  2.53s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:12,  1.57s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.27s/batch]
# Validation round:  40%|████      | 4/10 [00:05<00:06,  1.12s/batch]
# Validation round:  50%|█████     | 5/10 [00:06<00:05,  1.04s/batch]
# Validation round:  60%|██████    | 6/10 [00:07<00:03,  1.01batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.04batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.06batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.08batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.09batch/s]
# Validation Dice score: 0.7839446067810059
# Epoch 6/30: 100%|██████████| 1920/1920 [03:08<00:00, 12.81img/s, loss (batch)=0.435]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.76s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.25s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.04batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Epoch 6/30: 100%|██████████| 1920/1920 [03:18<00:00,  9.68img/s, loss (batch)=0.435]
# Validation Dice score: 0.7816049456596375
# Checkpoint 6 saved!
# Epoch 7/30:  20%|██        | 384/1920 [00:30<01:57, 13.06img/s, loss (batch)=0.57]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.77s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.04batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.7981903553009033
# Epoch 7/30:  40%|████      | 768/1920 [01:09<01:29, 12.82img/s, loss (batch)=0.429]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:16,  1.80s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.27s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.7915529608726501
# Epoch 7/30:  60%|██████    | 1152/1920 [01:48<01:00, 12.78img/s, loss (batch)=0.4]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.76s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.25s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.7975713610649109
# Epoch 7/30:  80%|████████  | 1536/1920 [02:27<00:30, 12.77img/s, loss (batch)=0.542]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:22,  2.50s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:12,  1.56s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.26s/batch]
# Validation round:  40%|████      | 4/10 [00:05<00:06,  1.12s/batch]
# Validation round:  50%|█████     | 5/10 [00:06<00:05,  1.04s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.01batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.05batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.07batch/s]
# Epoch 7/30:  80%|████████  | 1536/1920 [02:38<00:30, 12.77img/s, loss (batch)=0.542]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Validation Dice score: 0.7934399843215942
# Epoch 7/30: 100%|██████████| 1920/1920 [03:07<00:00, 12.82img/s, loss (batch)=0.425]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:17,  1.96s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.34s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:08,  1.19s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.07s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:05,  1.03s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.01batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.03batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.05batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.07batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.09batch/s]
# Epoch 7/30: 100%|██████████| 1920/1920 [03:18<00:00,  9.68img/s, loss (batch)=0.425]
# Validation Dice score: 0.7993943095207214
# Checkpoint 7 saved!
# Epoch 8/30:  20%|██        | 384/1920 [00:30<01:57, 13.06img/s, loss (batch)=0.422]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:16,  1.78s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.10s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.04batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.8039809465408325
# Epoch 8/30:  40%|████      | 768/1920 [01:09<01:30, 12.79img/s, loss (batch)=0.43]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:16,  1.78s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.10s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Epoch 8/30:  40%|████      | 768/1920 [01:19<01:30, 12.79img/s, loss (batch)=0.43]
# Validation Dice score: 0.8005965352058411
# Epoch 8/30:  60%|██████    | 1152/1920 [01:48<00:59, 12.81img/s, loss (batch)=0.514]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.75s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.25s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.7733175158500671
# Epoch 8/30:  80%|████████  | 1536/1920 [02:28<00:30, 12.79img/s, loss (batch)=0.41]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:21,  2.35s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:11,  1.49s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.22s/batch]
# Validation round:  40%|████      | 4/10 [00:05<00:06,  1.10s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:05,  1.02s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.02batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.05batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.07batch/s]
# Epoch 8/30:  80%|████████  | 1536/1920 [02:38<00:30, 12.79img/s, loss (batch)=0.41]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Validation Dice score: 0.8072320222854614
# Epoch 8/30: 100%|██████████| 1920/1920 [03:07<00:00, 12.78img/s, loss (batch)=0.541]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:17,  1.94s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.33s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:08,  1.15s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.05s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.00batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.04batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.06batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Epoch 8/30: 100%|██████████| 1920/1920 [03:18<00:00,  9.69img/s, loss (batch)=0.541]
# Validation Dice score: 0.8031164407730103
# Checkpoint 8 saved!
# Epoch 9/30:  20%|██        | 384/1920 [00:30<01:57, 13.07img/s, loss (batch)=0.544]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.72s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.25s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.10s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.04batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.7964245676994324
# Epoch 9/30:  40%|████      | 768/1920 [01:09<01:30, 12.80img/s, loss (batch)=0.466]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.77s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.7980644702911377
# Epoch 9/30:  60%|██████    | 1152/1920 [01:48<00:59, 12.80img/s, loss (batch)=0.465]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:16,  1.78s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.7982270121574402
# Epoch 9/30:  80%|████████  | 1536/1920 [02:27<00:29, 12.81img/s, loss (batch)=0.407]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.74s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.24s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.10s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.8077027201652527
# Epoch 9/30: 100%|██████████| 1920/1920 [03:07<00:00, 12.83img/s, loss (batch)=0.518]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.73s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.24s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Epoch 9/30: 100%|██████████| 1920/1920 [03:17<00:00,  9.74img/s, loss (batch)=0.518]
# Validation Dice score: 0.7885557413101196
# Checkpoint 9 saved!
# Epoch 10/30:  20%|██        | 384/1920 [00:30<01:57, 13.05img/s, loss (batch)=0.565]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.74s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.24s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.7282854914665222
# Epoch 10/30:  40%|████      | 768/1920 [01:09<01:30, 12.77img/s, loss (batch)=0.392]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.71s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.23s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.08s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:07<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.8083826899528503
# Epoch 10/30:  60%|██████    | 1152/1920 [01:48<00:59, 12.80img/s, loss (batch)=0.706]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:20,  2.23s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:11,  1.45s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.20s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.08s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:05,  1.01s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.03batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.06batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Validation Dice score: 0.7900919318199158
# Epoch 10/30:  80%|████████  | 1536/1920 [02:28<00:30, 12.76img/s, loss (batch)=0.448]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:21,  2.42s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:12,  1.53s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.24s/batch]
# Validation round:  40%|████      | 4/10 [00:05<00:06,  1.10s/batch]
# Validation round:  50%|█████     | 5/10 [00:06<00:05,  1.04s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.01batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.04batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.07batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.08batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.09batch/s]
# Validation Dice score: 0.8105801939964294
# Epoch 10/30: 100%|██████████| 1920/1920 [03:08<00:00, 12.79img/s, loss (batch)=0.42]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.68s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.22s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.07s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.00s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:07<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Epoch 10/30: 100%|██████████| 1920/1920 [03:18<00:00,  9.69img/s, loss (batch)=0.42]
# Validation Dice score: 0.8118178248405457
# Checkpoint 10 saved!
# Epoch 11/30:  20%|██        | 384/1920 [00:30<01:57, 13.02img/s, loss (batch)=0.4]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.76s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.25s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.8089276552200317
# Epoch 11/30:  40%|████      | 768/1920 [01:09<01:30, 12.80img/s, loss (batch)=0.47]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:16,  1.80s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.27s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.10s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.8081321716308594
# Epoch 11/30:  60%|██████    | 1152/1920 [01:48<00:59, 12.82img/s, loss (batch)=0.406]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.69s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.22s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.07s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.00s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:07<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.8111526370048523
# Epoch 11/30:  80%|████████  | 1536/1920 [02:27<00:29, 12.82img/s, loss (batch)=0.418]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:22,  2.49s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:12,  1.55s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.25s/batch]
# Validation round:  40%|████      | 4/10 [00:05<00:06,  1.12s/batch]
# Validation round:  50%|█████     | 5/10 [00:06<00:05,  1.04s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.01batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.04batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.07batch/s]
# ...
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.25s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.8239333033561707
# Epoch 27/30:  80%|████████  | 1536/1920 [02:28<00:30, 12.79img/s, loss (batch)=0.424]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.70s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.23s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.08s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:07<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.8232325911521912
# Epoch 27/30: 100%|██████████| 1920/1920 [03:07<00:00, 12.80img/s, loss (batch)=0.375]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:20,  2.22s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:11,  1.44s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.19s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.08s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:05,  1.01s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.03batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.06batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Epoch 27/30: 100%|██████████| 1920/1920 [03:18<00:00, 12.80img/s, loss (batch)=0.375]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Epoch 27/30: 100%|██████████| 1920/1920 [03:18<00:00,  9.69img/s, loss (batch)=0.375]
# Validation Dice score: 0.8246354460716248
# Checkpoint 27 saved!
# Epoch 28/30:  20%|██        | 384/1920 [00:30<01:58, 12.95img/s, loss (batch)=0.368]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:16,  1.80s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.10s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.03s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.01batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.04batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.06batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Epoch 28/30:  20%|██        | 384/1920 [00:40<01:58, 12.95img/s, loss (batch)=0.368]
# Validation Dice score: 0.8242389559745789
# Epoch 28/30:  40%|████      | 768/1920 [01:09<01:30, 12.79img/s, loss (batch)=0.407]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:18,  2.03s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.36s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:08,  1.15s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.05s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.00batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.04batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.11batch/s]
# Validation Dice score: 0.8251171112060547
# Epoch 28/30:  60%|██████    | 1152/1920 [01:49<01:00, 12.72img/s, loss (batch)=0.357]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:21,  2.36s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:11,  1.50s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.23s/batch]
# Validation round:  40%|████      | 4/10 [00:05<00:06,  1.10s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:05,  1.03s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.02batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.05batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.07batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Validation Dice score: 0.8239636421203613
# Epoch 28/30:  80%|████████  | 1536/1920 [02:29<00:30, 12.76img/s, loss (batch)=0.366]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.74s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.24s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.8234006762504578
# Epoch 28/30: 100%|██████████| 1920/1920 [03:08<00:00, 12.86img/s, loss (batch)=0.41]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.71s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.23s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.08s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:07<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Epoch 28/30: 100%|██████████| 1920/1920 [03:18<00:00,  9.68img/s, loss (batch)=0.41]
# Validation Dice score: 0.8234081268310547
# Checkpoint 28 saved!
# Epoch 29/30:  20%|██        | 384/1920 [00:30<01:57, 13.07img/s, loss (batch)=0.407]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.76s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.8237788081169128
# Epoch 29/30:  40%|████      | 768/1920 [01:09<01:29, 12.81img/s, loss (batch)=0.406]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.74s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.25s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.06batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.8254470825195312
# Epoch 29/30:  60%|██████    | 1152/1920 [01:48<00:59, 12.83img/s, loss (batch)=0.402]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:20,  2.32s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:11,  1.48s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.21s/batch]
# Validation round:  40%|████      | 4/10 [00:05<00:06,  1.09s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:05,  1.02s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.02batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.05batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.07batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Validation Dice score: 0.8235397338867188
# Epoch 29/30:  80%|████████  | 1536/1920 [02:28<00:30, 12.77img/s, loss (batch)=0.398]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:16,  1.86s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.30s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.12s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.04s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.01batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.04batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.8247694373130798
# Epoch 29/30: 100%|██████████| 1920/1920 [03:07<00:00, 12.80img/s, loss (batch)=0.37]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:16,  1.79s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.27s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.10s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Epoch 29/30: 100%|██████████| 1920/1920 [03:17<00:00,  9.71img/s, loss (batch)=0.37]
# Validation Dice score: 0.8247544169425964
# Checkpoint 29 saved!
# Epoch 30/30:  20%|██        | 384/1920 [00:30<01:57, 13.05img/s, loss (batch)=0.353]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.73s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.24s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.09s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.8246746063232422
# Epoch 30/30:  40%|████      | 768/1920 [01:09<01:30, 12.77img/s, loss (batch)=0.403]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.71s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.23s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.08s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.07batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.08batch/s]
# Validation round:  80%|████████  | 8/10 [00:07<00:01,  1.10batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Validation Dice score: 0.8249484300613403
# Epoch 30/30:  60%|██████    | 1152/1920 [01:48<01:00, 12.74img/s, loss (batch)=0.391]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:02<00:20,  2.32s/batch]
# Validation round:  20%|██        | 2/10 [00:03<00:11,  1.48s/batch]
# Validation round:  30%|███       | 3/10 [00:04<00:08,  1.22s/batch]
# Validation round:  40%|████      | 4/10 [00:05<00:06,  1.09s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:05,  1.02s/batch]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.02batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.05batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.07batch/s]
# Validation round:  90%|█████████ | 9/10 [00:09<00:00,  1.09batch/s]
# Validation round: 100%|██████████| 10/10 [00:10<00:00,  1.10batch/s]
# Validation Dice score: 0.8231396675109863
# Epoch 30/30:  80%|████████  | 1536/1920 [02:28<00:30, 12.77img/s, loss (batch)=0.421]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.75s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:10,  1.26s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.10s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.02s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.02batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.08batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.10batch/s]
# Validation Dice score: 0.825605034828186
# Epoch 30/30: 100%|██████████| 1920/1920 [03:07<00:00, 12.87img/s, loss (batch)=0.407]
# Validation round:   0%|          | 0/10 [00:00<?, ?batch/s]
# Validation round:  10%|█         | 1/10 [00:01<00:15,  1.68s/batch]
# Validation round:  20%|██        | 2/10 [00:02<00:09,  1.23s/batch]
# Validation round:  30%|███       | 3/10 [00:03<00:07,  1.08s/batch]
# Validation round:  40%|████      | 4/10 [00:04<00:06,  1.01s/batch]
# Validation round:  50%|█████     | 5/10 [00:05<00:04,  1.03batch/s]
# Validation round:  60%|██████    | 6/10 [00:06<00:03,  1.05batch/s]
# Validation round:  70%|███████   | 7/10 [00:07<00:02,  1.07batch/s]
# Validation round:  80%|████████  | 8/10 [00:08<00:01,  1.09batch/s]
# Validation round:  90%|█████████ | 9/10 [00:08<00:00,  1.10batch/s]
# Validation round: 100%|██████████| 10/10 [00:09<00:00,  1.11batch/s]
# Epoch 30/30: 100%|██████████| 1920/1920 [03:17<00:00,  9.71img/s, loss (batch)=0.407]
# Validation Dice score: 0.8256420493125916
# Checkpoint 30 saved!

# %% [markdown]
# # Results

# %%
latest_checkpoint = sorted(dir_checkpoint.iterdir(), key=os.path.getmtime)[-1]
model.load_state_dict(torch.load(latest_checkpoint, map_location=device))
model.eval()

n_rows = 4
fig, axs = plt.subplots(n_rows, 3, figsize=(20, 20))
axs[0, 0].set_title("RGB from bands")
axs[0, 1].set_title("Predicted mask")
axs[0, 2].set_title("Ground truth mask")

for i in range(n_rows):
    image, mask = val_set[i].values()

    img = np.array(image)[0:3,...].transpose(1, 2, 0)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    #Move image to GPU
    image = image.to(device)
    mask_pred = model(torch.unsqueeze(image, dim=0))
    mask_pred = (F.sigmoid(mask_pred) > 0.9).float()
    #Move mask_pred back to CPU
    mask_pred = mask_pred.cpu()


    axs[i, 0].imshow(img)
    axs[i, 1].imshow(torch.squeeze(mask_pred.detach()), cmap="gray")
    axs[i, 2].imshow(mask, cmap="gray")

# %%
print(model)
# Out:
# UNet(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(7, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down2): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down3): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down4): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (up1): Up(
#     (up): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up2): Up(
#     (up): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up3): Up(
#     (up): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up4): Up(
#     (up): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (outc): OutConv(
#     (conv): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
# data_path = Path("/content/drive/MyDrive/Omdena/Ladakh/split/0.07-256x256/2009")
# dataset = LandsatDataset(data_path)

# train_set, val_set = random_split(dataset, [n_train, n_val], generator=torch.Generator().manual_seed(0))

# loader_args = dict(batch_size=10, num_workers=os.cpu_count(), pin_memory=True)
# val_loader = DataLoader(val_set, shuffle=False, drop_last=True, **loader_args)

# evaluate(model, val_loader, device, amp)
